# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test/255.0
y_train = (y_train % 2).astype("int32")
y_test = (y_test % 2).astype("int32")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 4s 0us/step

# %%
model = Sequential([Flatten(input_shape = (28, 28)),
                  Dense(64, activation = "relu"),
                  Dense(32, activation = "relu"),
                  Dense(1, activation = "relu")])

# %%
model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])
model.fit(x_train, y_train, epochs = 10, validation_data = (x_test, y_test))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 7.8431 - accuracy: 0.4915 - val_loss: 7.8266 - val_accuracy: 0.4926
# Epoch 2/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 7.8431 - accuracy: 0.4915 - val_loss: 7.8266 - val_accuracy: 0.4926
# Epoch 3/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 7.8431 - accuracy: 0.4915 - val_loss: 7.8266 - val_accuracy: 0.4926
# Epoch 4/10
# 1875/1875 [==============================] - 2s 1ms/step - loss: 7.8431 - accuracy: 0.4915 - val_loss: 7.8266 - val_accuracy: 0.4926
# Epoch 5/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 7.8431 - accuracy: 0.4915 - val_loss: 7.8266 - val_accuracy: 0.4926
# Epoch 6/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 7.8431 - accuracy: 0.4915 - val_loss: 7.8266 - val_accuracy: 0.4926
# Epoch 7/10
# 1875/1875 [==============================] - 3s 1ms/step - loss: 7.8431 - accuracy: 0.4915 - val_loss: 7.8266 - val_accuracy: 0.4926
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 7.8431 - accuracy: 0.4915 - val_loss: 7.8266 - val_accuracy: 0.4926
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 7.8431 - accuracy: 0.4915 - val_loss: 7.8266 - val_accuracy: 0.4926
# Epoch 10/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 7.8431 - accuracy: 0.4915 - val_loss: 7.8266 - val_accuracy: 0.4926

# %%
loss, accuracy = model.evaluate(x_test, y_test)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy:.4f}")
# Out:
# 313/313 [==============================] - 0s 892us/step - loss: 7.8266 - accuracy: 0.4926
# Loss: 7.8266
# Accuracy: 0.4926
