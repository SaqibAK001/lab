# %%
import tensorflow as tf 
from tensorflow.keras.datasets import cifar10 
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout 
from tensorflow.keras.utils import to_categorical

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data() 

x_train, x_test = x_train / 255.0, x_test / 255.0 

y_train = to_categorical(y_train, num_classes=10) 
y_test = to_categorical(y_test, num_classes=10)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 46s 0us/step

# %%
datagen = ImageDataGenerator(horizontal_flip=True,)

datagen.fit(x_train)

# %%
model = Sequential([ 
            Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=x_train.shape[1:]), 
            MaxPooling2D((2, 2)), 
            Dropout(0.25), 
            Conv2D(64, (3, 3), activation='relu', padding='same'), 
            MaxPooling2D((2, 2)), 
            Dropout(0.25),  
            Flatten(), 
            Dense(512, activation='relu'), 
            Dropout(0.5), 
            Dense(10, activation='softmax') 
        ])

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(datagen.flow(x_train, y_train, batch_size=64), epochs=5, validation_data=(x_test, y_test))
# Out:
# Epoch 1/5
# 782/782 [==============================] - 52s 65ms/step - loss: 1.6050 - accuracy: 0.4179 - val_loss: 1.2690 - val_accuracy: 0.5528
# Epoch 2/5
# 782/782 [==============================] - 51s 65ms/step - loss: 1.2489 - accuracy: 0.5547 - val_loss: 1.0506 - val_accuracy: 0.6332
# Epoch 3/5
# 782/782 [==============================] - 48s 61ms/step - loss: 1.1260 - accuracy: 0.6004 - val_loss: 0.9752 - val_accuracy: 0.6647
# Epoch 4/5
# 782/782 [==============================] - 49s 63ms/step - loss: 1.0497 - accuracy: 0.6289 - val_loss: 0.9083 - val_accuracy: 0.6854
# Epoch 5/5
# 782/782 [==============================] - 48s 61ms/step - loss: 0.9951 - accuracy: 0.6502 - val_loss: 0.8790 - val_accuracy: 0.7001

# %%
accuracy = model.evaluate(x_test, y_test, verbose=0)[1]

print(f"Test Accuracy: {accuracy * 100:.2f}%")
# Out:
# Test Accuracy: 70.01%
